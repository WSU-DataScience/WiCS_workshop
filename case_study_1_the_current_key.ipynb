# %% [markdown]
# # Case Study - The Current
#
# * The Current is an alternative radio station
# * We will pull information about the play list.

# %% [markdown]
# ## <font color="red">Exercise - Go the the following page and inspect the following </font>
#
# * Song title
# * Artist
# * Play time
# * Day, date, period (am/pm)
#
# http://www.thecurrent.org/playlist/2014-01-01/01

# %%
import requests
import bs4
import datetime

# %%
example_url = 'http://www.thecurrent.org/playlist/2014-01-01/01'
s = requests.Session()
r = s.get(example_url)

soup = bs4.BeautifulSoup(r.content, "lxml")

# %% [markdown]
# # Pull off the period of the day (am/pm)
#
# Pull out the "am"/"pm"
#
# 1. Inspect the element
# 2. Identify the html tag and class
# 3. Search the soup
#     1. There should be one item returned
# 4. Use soup\string methods to pull out the info

# %%
# I should have used find here...Why?
soup('span', class_="hour-header open")
# Out:
# [<span class="hour-header open">
#       1:00 am to  2:00 am
#    </span>]

# %%
len(soup('span', class_="hour-header open"))
# Out:
# 1

# %%
soup('span', class_="hour-header open")[0]
# Out:
# <span class="hour-header open">
#      1:00 am to  2:00 am
#   </span>

# %%
soup('span', class_="hour-header open")[0].next
# Out:
# '\n     1:00 am to  2:00 am\n  '

# %%
soup('span', class_="hour-header open")[0].next.split('to')
# Out:
# ['\n     1:00 am ', '  2:00 am\n  ']

# %%
soup('span', class_="hour-header open")[0].next.split('to')[0]
# Out:
# '\n     1:00 am '

# %%
soup('span', class_="hour-header open")[0].next.split('to')[0].rstrip()
# Out:
# '\n     1:00 am'

# %%
period = soup('span', class_="hour-header open")[0].next.split('to')[0].rstrip()[-2:]
period
# Out:
# 'am'

# %% [markdown]
# ## <font color="red"> Breakout activity </font>
#
# * Pull out the day of the week

# %%
soup('a', class_="start-picker")
# Out:
# [<a class="start-picker" href="#archives">Wednesday, Jan 01, 2014</a>]

# %%
soup('a', class_="start-picker")[0]
# Out:
# <a class="start-picker" href="#archives">Wednesday, Jan 01, 2014</a>

# %%
soup('a', class_="start-picker")[0].next
# Out:
# 'Wednesday, Jan 01, 2014'

# %%
soup('a', class_="start-picker")[0].next.split(',')
# Out:
# ['Wednesday', ' Jan 01', ' 2014']

# %%
day_of_week = soup('a', class_="start-picker")[0].next.split(',')[0]
day_of_week
# Out:
# 'Wednesday'

# %% [markdown]
# # Title of each song
#
# 1. Inspect the element
# 2. Identify the html tag and class
# 3. Use `soup.findAll` to make a list of all relevant tags
# 4. Pull off an example case
# 5. Use soup/string methods to pull out the title
# 6. Use a list comprehension to process all tags

# %%
soup.findAll('h5', class_ = "title")
# Out:
# [<h5 class="title">Holy Roller
#          <h5 class="artist">Thao and The Get Down Stay Down
#        </h5></h5>, <h5 class="title">Kingdom of Rust
#          <h5 class="artist">Doves
#        </h5></h5>, <h5 class="title">Black Dog
#          <h5 class="artist">Frankie Lee
#        </h5></h5>, <h5 class="title">Turn It Around
#          <h5 class="artist">Lucius
#        </h5></h5>, <h5 class="title">Flavor of the Month
#          <h5 class="artist">The Posies
#        </h5></h5>, <h5 class="title">Potential Wife
#          <h5 class="artist">Strange Names
#        </h5></h5>, <h5 class="title">24 Hours
#          <h5 class="artist">Sky Ferreira
#        </h5></h5>, <h5 class="title">Who's Gonna Shoe Your Pretty Little Feet?
#          <h5 class="artist">Billie Joe and Norah
#        </h5></h5>, <h5 class="title">Marigold
#          <h5 class="artist">J. Roddy Walston and The Business
#        </h5></h5>, <h5 class="title">High Road
#          <h5 class="artist">Cults
#        </h5></h5>, <h5 class="title">The Vampyre Of Time and Memory
#          <h5 class="artist">Queens of the Stone Age
#        </h5></h5>, <h5 class="title">Valerie Plame
#          <h5 class="artist">The Decemberists
#        </h5></h5>, <h5 class="title">Morning Song
#          <h5 class="artist">The Avett Brothers
#        </h5></h5>, <h5 class="title">(You Will) Set The World On Fire
#          <h5 class="artist">David Bowie
#        </h5></h5>, <h5 class="title">Sixteen Saltines
#          <h5 class="artist">Jack White
#        </h5></h5>, <h5 class="title">Wave of Mutilation
#          <h5 class="artist">Pixies
#        </h5></h5>]

# %%
example_tag =  soup.findAll('h5', class_ = "title")[0]
example_tag
# Out:
# <h5 class="title">Holy Roller
#         <h5 class="artist">Thao and The Get Down Stay Down
#       </h5></h5>

# %%
example_tag.next
# Out:
# 'Holy Roller\n        '

# %%
example_tag.next.strip()
# Out:
# 'Holy Roller'

# %%
titles = [tag.next.strip() for tag in soup.findAll('h5', class_ = "title")]
titles
# Out:
# ['Holy Roller',
#  'Kingdom of Rust',
#  'Black Dog',
#  'Turn It Around',
#  'Flavor of the Month',
#  'Potential Wife',
#  '24 Hours',
#  "Who's Gonna Shoe Your Pretty Little Feet?",
#  'Marigold',
#  'High Road',
#  'The Vampyre Of Time and Memory',
#  'Valerie Plame',
#  'Morning Song',
#  '(You Will) Set The World On Fire',
#  'Sixteen Saltines',
#  'Wave of Mutilation']

# %% [markdown]
# ## <font color="red"> Break out session - Name of the Artist </font>
#
# 1. Inspect the element
# 2. Identify the html tag and class
# 3. Use `soup.findAll` to make a list of all relevant tags
# 4. Pull off an example case
# 5. Use soup/string methods to pull out the title
# 6. Use a list comprehension to process all tags

# %%
soup.findAll('h5',class_='artist')
# Out:
# [<h5 class="artist">Thao and The Get Down Stay Down
#        </h5>, <h5 class="artist">Doves
#        </h5>, <h5 class="artist">Frankie Lee
#        </h5>, <h5 class="artist">Lucius
#        </h5>, <h5 class="artist">The Posies
#        </h5>, <h5 class="artist">Strange Names
#        </h5>, <h5 class="artist">Sky Ferreira
#        </h5>, <h5 class="artist">Billie Joe and Norah
#        </h5>, <h5 class="artist">J. Roddy Walston and The Business
#        </h5>, <h5 class="artist">Cults
#        </h5>, <h5 class="artist">Queens of the Stone Age
#        </h5>, <h5 class="artist">The Decemberists
#        </h5>, <h5 class="artist">The Avett Brothers
#        </h5>, <h5 class="artist">David Bowie
#        </h5>, <h5 class="artist">Jack White
#        </h5>, <h5 class="artist">Pixies
#        </h5>]

# %%
example_tag =soup.findAll('h5',class_='artist')[0] 
example_tag
# Out:
# <h5 class="artist">Thao and The Get Down Stay Down
#       </h5>

# %%
example_tag.next
# Out:
# 'Thao and The Get Down Stay Down\n      '

# %%
example_tag.next.strip()
# Out:
# 'Thao and The Get Down Stay Down'

# %%
artists = [tag.next.strip() for tag in  soup.findAll('h5',class_='artist')]
artists
# Out:
# ['Thao and The Get Down Stay Down',
#  'Doves',
#  'Frankie Lee',
#  'Lucius',
#  'The Posies',
#  'Strange Names',
#  'Sky Ferreira',
#  'Billie Joe and Norah',
#  'J. Roddy Walston and The Business',
#  'Cults',
#  'Queens of the Stone Age',
#  'The Decemberists',
#  'The Avett Brothers',
#  'David Bowie',
#  'Jack White',
#  'Pixies']

# %% [markdown]
# ## <font color="red"> Break out session - song start time </font>
#
# 1. Inspect the element
#     1. This one is tricky
#     2. Time tag does not have a tag, but
#     3. The surrounding div does have a class
# 2. Identify the html tag and class
# 3. Use `soup.findAll` to make a list of all relevant tags
# 4. Pull off an example case
# 5. Use soup/string methods to pull out the title
# 6. Use a list comprehension to process all tags

# %%
soup.findAll('time')
# Out:
# [<time datetime="2017-05-11">
#                10 a.m.
#              </time>, <time datetime="2017-05-11">
#                 2 p.m.
#              </time>, <time datetime="2017-05-11">
#                 6 p.m.
#              </time>, <time datetime="2017-05-11">
#                10 p.m.
#              </time>, <time datetime="2017-05-11">
#                11 p.m.
#              </time>, <time datetime="2017-05-12">5/12</time>, <time datetime="2017-05-18">5/18</time>, <time datetime="2017-09-29">9/29</time>, <time>  1:59 </time>, <time>  1:54 </time>, <time>  1:51 </time>, <time>  1:46 </time>, <time>  1:44 </time>, <time>  1:38 </time>, <time>  1:34 </time>, <time>  1:31 </time>, <time>  1:27 </time>, <time>  1:23 </time>, <time>  1:19 </time>, <time>  1:13 </time>, <time>  1:09 </time>, <time>  1:05 </time>, <time>  1:03 </time>, <time>  1:01 </time>]

# %%
tags = soup('div', class_="two columns songTime")
tags
# Out:
# [<div class="two columns songTime">
#  <a href="#song226645">
#  <time>  1:59 </time>
#  </a>
#  </div>, <div class="two columns songTime">
#  <a href="#song196069">
#  <time>  1:54 </time>
#  </a>
#  </div>, <div class="two columns songTime">
#  <a href="#song229900">
#  <time>  1:51 </time>
#  </a>
#  </div>, <div class="two columns songTime">
#  <a href="#song235779">
#  <time>  1:46 </time>
#  </a>
#  </div>, <div class="two columns songTime">
#  <a href="#song132616">
#  <time>  1:44 </time>
#  </a>
#  </div>, <div class="two columns songTime">
#  <a href="#song224268">
#  <time>  1:38 </time>
#  </a>
#  </div>, <div class="two columns songTime">
#  <a href="#song236492">
#  <time>  1:34 </time>
#  </a>
#  </div>, <div class="two columns songTime">
#  <a href="#song237794">
#  <time>  1:31 </time>
#  </a>
#  </div>, <div class="two columns songTime">
#  <a href="#song234211">
#  <time>  1:27 </time>
#  </a>
#  </div>, <div class="two columns songTime">
#  <a href="#song235959">
#  <time>  1:23 </time>
#  </a>
#  </div>, <div class="two columns songTime">
#  <a href="#song232235">
#  <time>  1:19 </time>
#  </a>
#  </div>, <div class="two columns songTime">
#  <a href="#song190810">
#  <time>  1:13 </time>
#  </a>
#  </div>, <div class="two columns songTime">
#  <a href="#song236192">
#  <time>  1:09 </time>
#  </a>
#  </div>, <div class="two columns songTime">
#  <a href="#song229658">
#  <time>  1:05 </time>
#  </a>
#  </div>, <div class="two columns songTime">
#  <a href="#song221276">
#  <time>  1:03 </time>
#  </a>
#  </div>, <div class="two columns songTime">
#  <a href="#song131853">
#  <time>  1:01 </time>
#  </a>
#  </div>]

# %%
example_tag = tags[0]
example_tag
# Out:
# <div class="two columns songTime">
# <a href="#song226645">
# <time>  1:59 </time>
# </a>
# </div>

# %%
example_tag.time
# Out:
# <time>  1:59 </time>

# %%
example_tag.time.next
# Out:
# '  1:59 '

# %%
example_tag.time.next.strip()
# Out:
# '1:59'

# %%
start_times = [tag.time.next.strip() for tag in  soup('div', class_="two columns songTime")]
start_times
# Out:
# ['1:59',
#  '1:54',
#  '1:51',
#  '1:46',
#  '1:44',
#  '1:38',
#  '1:34',
#  '1:31',
#  '1:27',
#  '1:23',
#  '1:19',
#  '1:13',
#  '1:09',
#  '1:05',
#  '1:03',
#  '1:01']

# %% [markdown]
# # Putting it all together

# %%
def get_period(soup):
    search = soup('span', class_="hour-header open")
    if len(search) > 0:
        return search[0].next.split('to')[0].rstrip()[-2:]
    else:
        return None

def get_day(soup):
    search = soup('a', class_="start-picker")
    if len(search) > 0:
        return search[0].next.split(',')[0]
    else:
        return None
    
def get_song_info(url):
    print("Starting {0} urls".format(url))
    date = url.split('/')[-2]
    s = requests.Session()
    r = s.get(url)
    soup = bs4.BeautifulSoup(r.content, 'lxml')
    period = get_period(soup)
    day_of_week = get_day(soup)
    soup = bs4.BeautifulSoup(r.content)
    titles = [t.next.strip() for t in soup.findAll('h5', class_="title")]
    artists = [a.next.strip() for a in soup.findAll('h5',class_='artist')]
    times = [d.time.next.strip() for d in soup('div', class_="two columns songTime")]
    song_info = [(day_of_week, date, time, period, title, artist) 
             for time, title, artist in zip(times, titles, artists)]
    return song_info

# %%
get_song_info(example_url)
# Out:
# Starting http://www.thecurrent.org/playlist/2014-01-01/01 urls
# /Users/tiverson/.pyenv/versions/anaconda3-4.1.0/lib/python3.5/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# [('Wednesday',
#   '2014-01-01',
#   '1:59',
#   'am',
#   'Holy Roller',
#   'Thao and The Get Down Stay Down'),
#  ('Wednesday', '2014-01-01', '1:54', 'am', 'Kingdom of Rust', 'Doves'),
#  ('Wednesday', '2014-01-01', '1:51', 'am', 'Black Dog', 'Frankie Lee'),
#  ('Wednesday', '2014-01-01', '1:46', 'am', 'Turn It Around', 'Lucius'),
#  ('Wednesday',
#   '2014-01-01',
#   '1:44',
#   'am',
#   'Flavor of the Month',
#   'The Posies'),
#  ('Wednesday', '2014-01-01', '1:38', 'am', 'Potential Wife', 'Strange Names'),
#  ('Wednesday', '2014-01-01', '1:34', 'am', '24 Hours', 'Sky Ferreira'),
#  ('Wednesday',
#   '2014-01-01',
#   '1:31',
#   'am',
#   "Who's Gonna Shoe Your Pretty Little Feet?",
#   'Billie Joe and Norah'),
#  ('Wednesday',
#   '2014-01-01',
#   '1:27',
#   'am',
#   'Marigold',
#   'J. Roddy Walston and The Business'),
#  ('Wednesday', '2014-01-01', '1:23', 'am', 'High Road', 'Cults'),
#  ('Wednesday',
#   '2014-01-01',
#   '1:19',
#   'am',
#   'The Vampyre Of Time and Memory',
#   'Queens of the Stone Age'),
#  ('Wednesday',
#   '2014-01-01',
#   '1:13',
#   'am',
#   'Valerie Plame',
#   'The Decemberists'),
#  ('Wednesday',
#   '2014-01-01',
#   '1:09',
#   'am',
#   'Morning Song',
#   'The Avett Brothers'),
#  ('Wednesday',
#   '2014-01-01',
#   '1:05',
#   'am',
#   '(You Will) Set The World On Fire',
#   'David Bowie'),
#  ('Wednesday', '2014-01-01', '1:03', 'am', 'Sixteen Saltines', 'Jack White'),
#  ('Wednesday', '2014-01-01', '1:01', 'am', 'Wave of Mutilation', 'Pixies')]

# %% [markdown]
# # Collecting a years worth of data
#
# ## Step 1 - Identify the url pattern
#
# The Current uses urls of the following pattern
#
#     'http://www.thecurrent.org/playlist/2017-05-04/10'
#
# or
#
#     'http://www.thecurrent.org/playlist/year-month-day/hour'

# %% [markdown]
# ## Question: How might you generate all combinations for a given year?
#
# **Answer:** Python has a tool for that!

# %%
numdays = 365
base = datetime.datetime.today()
dts = [base - datetime.timedelta(hours = h) for h in range(0, numdays*24)]

# %%
def output_address(dt):
    fmt = 'http://www.thecurrent.org/playlist/%Y-%m-%d/%H'
    return dt.strftime(fmt)

def test_output_address():
    date = datetime.datetime(2000,1,1,1)
    assert output_address(date) == 'http://www.thecurrent.org/playlist/2000-01-01/01'
test_output_address()

# %%
urls = [output_address(d) for d in dts]
urls[:10]
# Out:
# ['http://www.thecurrent.org/playlist/2017-05-14/16',
#  'http://www.thecurrent.org/playlist/2017-05-14/15',
#  'http://www.thecurrent.org/playlist/2017-05-14/14',
#  'http://www.thecurrent.org/playlist/2017-05-14/13',
#  'http://www.thecurrent.org/playlist/2017-05-14/12',
#  'http://www.thecurrent.org/playlist/2017-05-14/11',
#  'http://www.thecurrent.org/playlist/2017-05-14/10',
#  'http://www.thecurrent.org/playlist/2017-05-14/09',
#  'http://www.thecurrent.org/playlist/2017-05-14/08',
#  'http://www.thecurrent.org/playlist/2017-05-14/07']

# %%
from toolz import pipe
from toolz.curried import take
from more_itertools import side_effect, consume

with open('the_current_last_year.csv', 'w') as outfile:
    header = "Weekday,Date,Time,Period,Song_Title,Artist"
    print(header, file=outfile)
    count = 0
    for url in urls:
        for song_info in get_song_info(url):
            count += 1
            if count % 5 == 0:
                print("Processed {0} songs".format(count))
            join_info = ",".join(song_info)
            print(join_info, file=outfile)
# Out:
# Starting http://www.thecurrent.org/playlist/2017-05-12/11 urls
# /Users/bn8210wy/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# Starting http://www.thecurrent.org/playlist/2017-05-12/10 urls
# Processed 5 songs
# Processed 10 songs
# Processed 15 songs
# Starting http://www.thecurrent.org/playlist/2017-05-12/09 urls
# Processed 20 songs
# Processed 25 songs
# Starting http://www.thecurrent.org/playlist/2017-05-12/08 urls
# Processed 30 songs
# Processed 35 songs
# Starting http://www.thecurrent.org/playlist/2017-05-12/07 urls
# Processed 40 songs
# Processed 45 songs
# Starting http://www.thecurrent.org/playlist/2017-05-12/06 urls
# Processed 50 songs
# Processed 55 songs
# Starting http://www.thecurrent.org/playlist/2017-05-12/05 urls
# Processed 60 songs
# Processed 65 songs
# Processed 70 songs
# Starting http://www.thecurrent.org/playlist/2017-05-12/04 urls
# Processed 75 songs
# Processed 80 songs
# Processed 85 songs
# Starting http://www.thecurrent.org/playlist/2017-05-12/03 urls
# Processed 90 songs
# Processed 95 songs
# Processed 100 songs
# Starting http://www.thecurrent.org/playlist/2017-05-12/02 urls
# Processed 105 songs
# Processed 110 songs
# Processed 115 songs
# Starting http://www.thecurrent.org/playlist/2017-05-12/01 urls
# Processed 120 songs
# Processed 125 songs
# Processed 130 songs
# Starting http://www.thecurrent.org/playlist/2017-05-12/00 urls
# Processed 135 songs
# Processed 140 songs
# Processed 145 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/23 urls
# Processed 150 songs
# Processed 155 songs
# Processed 160 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/22 urls
# Processed 165 songs
# Processed 170 songs
# Processed 175 songs
# Processed 180 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/21 urls
# Processed 185 songs
# Processed 190 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/20 urls
# Processed 195 songs
# Processed 200 songs
# Processed 205 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/19 urls
# Processed 210 songs
# Processed 215 songs
# Processed 220 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/18 urls
# Processed 225 songs
# Processed 230 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/17 urls
# Processed 235 songs
# Processed 240 songs
# Processed 245 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/16 urls
# Processed 250 songs
# Processed 255 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/15 urls
# Processed 260 songs
# Processed 265 songs
# Processed 270 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/14 urls
# Processed 275 songs
# Processed 280 songs
# Processed 285 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/13 urls
# Processed 290 songs
# Processed 295 songs
# Processed 300 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/12 urls
# Processed 305 songs
# Processed 310 songs
# Processed 315 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/11 urls
# Processed 320 songs
# Processed 325 songs
# Processed 330 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/10 urls
# Processed 335 songs
# Processed 340 songs
# Processed 345 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/09 urls
# Processed 350 songs
# Processed 355 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/08 urls
# Processed 360 songs
# Processed 365 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/07 urls
# Processed 370 songs
# Processed 375 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/06 urls
# Processed 380 songs
# Processed 385 songs
# Processed 390 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/05 urls
# Processed 395 songs
# Processed 400 songs
# Processed 405 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/04 urls
# Processed 410 songs
# Processed 415 songs
# Processed 420 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/03 urls
# Processed 425 songs
# Processed 430 songs
# Processed 435 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/02 urls
# Processed 440 songs
# Processed 445 songs
# Processed 450 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/01 urls
# Processed 455 songs
# Processed 460 songs
# Processed 465 songs
# Processed 470 songs
# Starting http://www.thecurrent.org/playlist/2017-05-11/00 urls
# Processed 475 songs
# Processed 480 songs
# Processed 485 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/23 urls
# Processed 490 songs
# Processed 495 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/22 urls
# Processed 500 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/21 urls
# Processed 505 songs
# Processed 510 songs
# Processed 515 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/20 urls
# Processed 520 songs
# Processed 525 songs
# Processed 530 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/19 urls
# Processed 535 songs
# Processed 540 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/18 urls
# Processed 545 songs
# Processed 550 songs
# Processed 555 songs
# Processed 560 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/17 urls
# Processed 565 songs
# Processed 570 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/16 urls
# Processed 575 songs
# Processed 580 songs
# Processed 585 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/15 urls
# Processed 590 songs
# Processed 595 songs
# Processed 600 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/14 urls
# Processed 605 songs
# Processed 610 songs
# Processed 615 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/13 urls
# Processed 620 songs
# Processed 625 songs
# Processed 630 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/12 urls
# Processed 635 songs
# Processed 640 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/11 urls
# Processed 645 songs
# Processed 650 songs
# Processed 655 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/10 urls
# Processed 660 songs
# Processed 665 songs
# Processed 670 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/09 urls
# Processed 675 songs
# Processed 680 songs
# Processed 685 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/08 urls
# Processed 690 songs
# Processed 695 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/07 urls
# Processed 700 songs
# Processed 705 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/06 urls
# Processed 710 songs
# Processed 715 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/05 urls
# Processed 720 songs
# Processed 725 songs
# Processed 730 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/04 urls
# Processed 735 songs
# Processed 740 songs
# Processed 745 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/03 urls
# Processed 750 songs
# Processed 755 songs
# Processed 760 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/02 urls
# Processed 765 songs
# Processed 770 songs
# Processed 775 songs
# Processed 780 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/01 urls
# Processed 785 songs
# Processed 790 songs
# Processed 795 songs
# Starting http://www.thecurrent.org/playlist/2017-05-10/00 urls
# Processed 800 songs
# Processed 805 songs
# Processed 810 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/23 urls
# Processed 815 songs
# Processed 820 songs
# Processed 825 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/22 urls
# Processed 830 songs
# Processed 835 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/21 urls
# Processed 840 songs
# Processed 845 songs
# Processed 850 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/20 urls
# Processed 855 songs
# Processed 860 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/19 urls
# Processed 865 songs
# Processed 870 songs
# Processed 875 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/18 urls
# Processed 880 songs
# Processed 885 songs
# Processed 890 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/17 urls
# Processed 895 songs
# Processed 900 songs
# Processed 905 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/16 urls
# Processed 910 songs
# Processed 915 songs
# Processed 920 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/15 urls
# Processed 925 songs
# Processed 930 songs
# Processed 935 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/14 urls
# Processed 940 songs
# Processed 945 songs
# Processed 950 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/13 urls
# Processed 955 songs
# Processed 960 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/12 urls
# Processed 965 songs
# Processed 970 songs
# Processed 975 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/11 urls
# Processed 980 songs
# Processed 985 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/10 urls
# Processed 990 songs
# Processed 995 songs
# Processed 1000 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/09 urls
# Processed 1005 songs
# Processed 1010 songs
# Processed 1015 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/08 urls
# Processed 1020 songs
# Processed 1025 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/07 urls
# Processed 1030 songs
# Processed 1035 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/06 urls
# Processed 1040 songs
# Processed 1045 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/05 urls
# Processed 1050 songs
# Processed 1055 songs
# Processed 1060 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/04 urls
# Processed 1065 songs
# Processed 1070 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/03 urls
# Processed 1075 songs
# Processed 1080 songs
# Processed 1085 songs
# Processed 1090 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/02 urls
# Processed 1095 songs
# Processed 1100 songs
# Processed 1105 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/01 urls
# Processed 1110 songs
# Processed 1115 songs
# Processed 1120 songs
# Starting http://www.thecurrent.org/playlist/2017-05-09/00 urls
# Processed 1125 songs
# Processed 1130 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/23 urls
# Processed 1135 songs
# Processed 1140 songs
# Processed 1145 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/22 urls
# Processed 1150 songs
# Processed 1155 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/21 urls
# Processed 1160 songs
# Processed 1165 songs
# Processed 1170 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/20 urls
# Processed 1175 songs
# Processed 1180 songs
# Processed 1185 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/19 urls
# Processed 1190 songs
# Processed 1195 songs
# Processed 1200 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/18 urls
# Processed 1205 songs
# Processed 1210 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/17 urls
# Processed 1215 songs
# Processed 1220 songs
# Processed 1225 songs
# Processed 1230 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/16 urls
# Processed 1235 songs
# Processed 1240 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/15 urls
# Processed 1245 songs
# Processed 1250 songs
# Processed 1255 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/14 urls
# Processed 1260 songs
# Processed 1265 songs
# Processed 1270 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/13 urls
# Processed 1275 songs
# Processed 1280 songs
# Processed 1285 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/12 urls
# Processed 1290 songs
# Processed 1295 songs
# Processed 1300 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/11 urls
# Processed 1305 songs
# Processed 1310 songs
# Processed 1315 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/10 urls
# Processed 1320 songs
# Processed 1325 songs
# Processed 1330 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/09 urls
# Processed 1335 songs
# Processed 1340 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/08 urls
# Processed 1345 songs
# Processed 1350 songs
# Processed 1355 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/07 urls
# Processed 1360 songs
# Processed 1365 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/06 urls
# Processed 1370 songs
# Processed 1375 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/05 urls
# Processed 1380 songs
# Processed 1385 songs
# Processed 1390 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/04 urls
# Processed 1395 songs
# Processed 1400 songs
# Processed 1405 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/03 urls
# Processed 1410 songs
# Processed 1415 songs
# Processed 1420 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/02 urls
# Processed 1425 songs
# Processed 1430 songs
# Processed 1435 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/01 urls
# Processed 1440 songs
# Processed 1445 songs
# Processed 1450 songs
# Starting http://www.thecurrent.org/playlist/2017-05-08/00 urls
# Processed 1455 songs
# Processed 1460 songs
# Processed 1465 songs
# Starting http://www.thecurrent.org/playlist/2017-05-07/23 urls
# Processed 1470 songs
# Processed 1475 songs
# Starting http://www.thecurrent.org/playlist/2017-05-07/22 urls
# Processed 1480 songs
# Processed 1485 songs
# Starting http://www.thecurrent.org/playlist/2017-05-07/21 urls
# Starting http://www.thecurrent.org/playlist/2017-05-07/20 urls
# Starting http://www.thecurrent.org/playlist/2017-05-07/19 urls
# Processed 1490 songs
# Processed 1495 songs
# Processed 1500 songs
# Starting http://www.thecurrent.org/playlist/2017-05-07/18 urls
# Processed 1505 songs
# Processed 1510 songs
# Processed 1515 songs
# Starting http://www.thecurrent.org/playlist/2017-05-07/17 urls
# Processed 1520 songs
# Processed 1525 songs
# Processed 1530 songs
# Starting http://www.thecurrent.org/playlist/2017-05-07/16 urls
# Processed 1535 songs
# Processed 1540 songs
# Processed 1545 songs
# Starting http://www.thecurrent.org/playlist/2017-05-07/15 urls
# Processed 1550 songs
# Processed 1555 songs
# Processed 1560 songs
# Starting http://www.thecurrent.org/playlist/2017-05-07/14 urls
# Processed 1565 songs
# Processed 1570 songs
# Processed 1575 songs
# Starting http://www.thecurrent.org/playlist/2017-05-07/13 urls
# Processed 1580 songs
# Processed 1585 songs
# Processed 1590 songs
# Starting http://www.thecurrent.org/playlist/2017-05-07/12 urls
# Processed 1595 songs
# Processed 1600 songs
# Starting http://www.thecurrent.org/playlist/2017-05-07/11 urls
# Processed 1605 songs
# Processed 1610 songs
# Processed 1615 songs
# Starting http://www.thecurrent.org/playlist/2017-05-07/10 urls
# Processed 1620 songs
# Processed 1625 songs
# Processed 1630 songs
# Starting http://www.thecurrent.org/playlist/2017-05-07/09 urls
# Processed 1635 songs
# Processed 1640 songs
# Processed 1645 songs
# Starting http://www.thecurrent.org/playlist/2017-05-07/08 urls
# Processed 1650 songs
# Processed 1655 songs
# Processed 1660 songs
# Starting http://www.thecurrent.org/playlist/2017-05-07/07 urls
# Starting http://www.thecurrent.org/playlist/2017-05-07/06 urls
# Starting http://www.thecurrent.org/playlist/2017-05-07/05 urls
# Processed 1665 songs
# Processed 1670 songs
# Processed 1675 songs
# Starting http://www.thecurrent.org/playlist/2017-05-07/04 urls
# Processed 1680 songs
# Processed 1685 songs
# Processed 1690 songs
# Starting http://www.thecurrent.org/playlist/2017-05-07/03 urls
# Processed 1695 songs
# Processed 1700 songs
# Processed 1705 songs
# Starting http://www.thecurrent.org/playlist/2017-05-07/02 urls
# Processed 1710 songs
# Processed 1715 songs
# Processed 1720 songs
# Starting http://www.thecurrent.org/playlist/2017-05-07/01 urls
# Processed 1725 songs
# Processed 1730 songs
# Processed 1735 songs
# Starting http://www.thecurrent.org/playlist/2017-05-07/00 urls
# Starting http://www.thecurrent.org/playlist/2017-05-06/23 urls
# Processed 1740 songs
# Processed 1745 songs
# Processed 1750 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/22 urls
# Processed 1755 songs
# Processed 1760 songs
# Processed 1765 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/21 urls
# Processed 1770 songs
# Processed 1775 songs
# Processed 1780 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/20 urls
# Processed 1785 songs
# Processed 1790 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/19 urls
# Processed 1795 songs
# Processed 1800 songs
# Processed 1805 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/18 urls
# Processed 1810 songs
# Processed 1815 songs
# Processed 1820 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/17 urls
# Processed 1825 songs
# Processed 1830 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/16 urls
# Processed 1835 songs
# Processed 1840 songs
# Processed 1845 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/15 urls
# Processed 1850 songs
# Processed 1855 songs
# Processed 1860 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/14 urls
# Processed 1865 songs
# Processed 1870 songs
# Processed 1875 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/13 urls
# Processed 1880 songs
# Processed 1885 songs
# Processed 1890 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/12 urls
# Processed 1895 songs
# Processed 1900 songs
# Processed 1905 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/11 urls
# Processed 1910 songs
# Processed 1915 songs
# Processed 1920 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/10 urls
# Processed 1925 songs
# Processed 1930 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/09 urls
# Processed 1935 songs
# Processed 1940 songs
# Processed 1945 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/08 urls
# Processed 1950 songs
# Processed 1955 songs
# Processed 1960 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/07 urls
# Processed 1965 songs
# Processed 1970 songs
# Processed 1975 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/06 urls
# Processed 1980 songs
# Processed 1985 songs
# Processed 1990 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/05 urls
# Processed 1995 songs
# Processed 2000 songs
# Processed 2005 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/04 urls
# Processed 2010 songs
# Processed 2015 songs
# Processed 2020 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/03 urls
# Processed 2025 songs
# Processed 2030 songs
# Processed 2035 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/02 urls
# Processed 2040 songs
# Processed 2045 songs
# Processed 2050 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/01 urls
# Processed 2055 songs
# Processed 2060 songs
# Processed 2065 songs
# Processed 2070 songs
# Starting http://www.thecurrent.org/playlist/2017-05-06/00 urls
# Processed 2075 songs
# Processed 2080 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/23 urls
# Processed 2085 songs
# Processed 2090 songs
# Processed 2095 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/22 urls
# Processed 2100 songs
# Processed 2105 songs
# Processed 2110 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/21 urls
# Processed 2115 songs
# Processed 2120 songs
# Processed 2125 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/20 urls
# Processed 2130 songs
# Processed 2135 songs
# Processed 2140 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/19 urls
# Processed 2145 songs
# Processed 2150 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/18 urls
# Processed 2155 songs
# Processed 2160 songs
# Processed 2165 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/17 urls
# Processed 2170 songs
# Processed 2175 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/16 urls
# Processed 2180 songs
# Processed 2185 songs
# Processed 2190 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/15 urls
# Processed 2195 songs
# Processed 2200 songs
# Processed 2205 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/14 urls
# Processed 2210 songs
# Processed 2215 songs
# Processed 2220 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/13 urls
# Processed 2225 songs
# Processed 2230 songs
# Processed 2235 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/12 urls
# Processed 2240 songs
# Processed 2245 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/11 urls
# Processed 2250 songs
# Processed 2255 songs
# Processed 2260 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/10 urls
# Processed 2265 songs
# Processed 2270 songs
# Processed 2275 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/09 urls
# Processed 2280 songs
# Processed 2285 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/08 urls
# Processed 2290 songs
# Processed 2295 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/07 urls
# Processed 2300 songs
# Processed 2305 songs
# Processed 2310 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/06 urls
# Processed 2315 songs
# Processed 2320 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/05 urls
# Processed 2325 songs
# Processed 2330 songs
# Processed 2335 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/04 urls
# Processed 2340 songs
# Processed 2345 songs
# Processed 2350 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/03 urls
# Processed 2355 songs
# Processed 2360 songs
# Processed 2365 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/02 urls
# Processed 2370 songs
# Processed 2375 songs
# Processed 2380 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/01 urls
# Processed 2385 songs
# Processed 2390 songs
# Processed 2395 songs
# Starting http://www.thecurrent.org/playlist/2017-05-05/00 urls
# Processed 2400 songs
# Processed 2405 songs
# Processed 2410 songs
# Processed 2415 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/23 urls
# Processed 2420 songs
# Processed 2425 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/22 urls
# Processed 2430 songs
# Processed 2435 songs
# Processed 2440 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/21 urls
# Processed 2445 songs
# Processed 2450 songs
# Processed 2455 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/20 urls
# Processed 2460 songs
# Processed 2465 songs
# Processed 2470 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/19 urls
# Processed 2475 songs
# Processed 2480 songs
# Processed 2485 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/18 urls
# Processed 2490 songs
# Processed 2495 songs
# Processed 2500 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/17 urls
# Processed 2505 songs
# Processed 2510 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/16 urls
# Processed 2515 songs
# Processed 2520 songs
# Processed 2525 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/15 urls
# Processed 2530 songs
# Processed 2535 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/14 urls
# Processed 2540 songs
# Processed 2545 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/13 urls
# Processed 2550 songs
# Processed 2555 songs
# Processed 2560 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/12 urls
# Processed 2565 songs
# Processed 2570 songs
# Processed 2575 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/11 urls
# Processed 2580 songs
# Processed 2585 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/10 urls
# Processed 2590 songs
# Processed 2595 songs
# Processed 2600 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/09 urls
# Processed 2605 songs
# Processed 2610 songs
# Processed 2615 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/08 urls
# Processed 2620 songs
# Processed 2625 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/07 urls
# Processed 2630 songs
# Processed 2635 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/06 urls
# Processed 2640 songs
# Processed 2645 songs
# Processed 2650 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/05 urls
# Processed 2655 songs
# Processed 2660 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/04 urls
# Processed 2665 songs
# Processed 2670 songs
# Processed 2675 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/03 urls
# Processed 2680 songs
# Processed 2685 songs
# Processed 2690 songs
# Processed 2695 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/02 urls
# Processed 2700 songs
# Processed 2705 songs
# Processed 2710 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/01 urls
# Processed 2715 songs
# Processed 2720 songs
# Processed 2725 songs
# Starting http://www.thecurrent.org/playlist/2017-05-04/00 urls
# Processed 2730 songs
# Processed 2735 songs
# Processed 2740 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/23 urls
# Processed 2745 songs
# Processed 2750 songs
# Processed 2755 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/22 urls
# Starting http://www.thecurrent.org/playlist/2017-05-03/21 urls
# Processed 2760 songs
# Processed 2765 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/20 urls
# Processed 2770 songs
# Processed 2775 songs
# Processed 2780 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/19 urls
# Processed 2785 songs
# Processed 2790 songs
# Processed 2795 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/18 urls
# Processed 2800 songs
# Processed 2805 songs
# Processed 2810 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/17 urls
# Processed 2815 songs
# Processed 2820 songs
# Processed 2825 songs
# Processed 2830 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/16 urls
# Processed 2835 songs
# Processed 2840 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/15 urls
# Processed 2845 songs
# Processed 2850 songs
# Processed 2855 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/14 urls
# Processed 2860 songs
# Processed 2865 songs
# Processed 2870 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/13 urls
# Processed 2875 songs
# Processed 2880 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/12 urls
# Processed 2885 songs
# Processed 2890 songs
# Processed 2895 songs
# Processed 2900 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/11 urls
# Processed 2905 songs
# Processed 2910 songs
# Processed 2915 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/10 urls
# Processed 2920 songs
# Processed 2925 songs
# Processed 2930 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/09 urls
# Processed 2935 songs
# Processed 2940 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/08 urls
# Processed 2945 songs
# Processed 2950 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/07 urls
# Processed 2955 songs
# Processed 2960 songs
# Processed 2965 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/06 urls
# Processed 2970 songs
# Processed 2975 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/05 urls
# Processed 2980 songs
# Processed 2985 songs
# Processed 2990 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/04 urls
# Processed 2995 songs
# Processed 3000 songs
# Processed 3005 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/03 urls
# Processed 3010 songs
# Processed 3015 songs
# Processed 3020 songs
# Processed 3025 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/02 urls
# Processed 3030 songs
# Processed 3035 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/01 urls
# Processed 3040 songs
# Processed 3045 songs
# Starting http://www.thecurrent.org/playlist/2017-05-03/00 urls
# Starting http://www.thecurrent.org/playlist/2017-05-02/23 urls
# Starting http://www.thecurrent.org/playlist/2017-05-02/22 urls
# Processed 3050 songs
# Processed 3055 songs
# Processed 3060 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/21 urls
# Processed 3065 songs
# Processed 3070 songs
# Processed 3075 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/20 urls
# Processed 3080 songs
# Processed 3085 songs
# Processed 3090 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/19 urls
# Processed 3095 songs
# Processed 3100 songs
# Processed 3105 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/18 urls
# Processed 3110 songs
# Processed 3115 songs
# Processed 3120 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/17 urls
# Processed 3125 songs
# Processed 3130 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/16 urls
# Processed 3135 songs
# Processed 3140 songs
# Processed 3145 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/15 urls
# Processed 3150 songs
# Processed 3155 songs
# Processed 3160 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/14 urls
# Processed 3165 songs
# Processed 3170 songs
# Processed 3175 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/13 urls
# Processed 3180 songs
# Processed 3185 songs
# Processed 3190 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/12 urls
# Processed 3195 songs
# Processed 3200 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/11 urls
# Processed 3205 songs
# Processed 3210 songs
# Processed 3215 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/10 urls
# Processed 3220 songs
# Processed 3225 songs
# Processed 3230 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/09 urls
# Processed 3235 songs
# Processed 3240 songs
# Processed 3245 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/08 urls
# Processed 3250 songs
# Processed 3255 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/07 urls
# Processed 3260 songs
# Processed 3265 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/06 urls
# Processed 3270 songs
# Processed 3275 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/05 urls
# Processed 3280 songs
# Processed 3285 songs
# Processed 3290 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/04 urls
# Processed 3295 songs
# Processed 3300 songs
# Processed 3305 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/03 urls
# Processed 3310 songs
# Processed 3315 songs
# Processed 3320 songs
# Processed 3325 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/02 urls
# Processed 3330 songs
# Processed 3335 songs
# Processed 3340 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/01 urls
# Processed 3345 songs
# Processed 3350 songs
# Processed 3355 songs
# Starting http://www.thecurrent.org/playlist/2017-05-02/00 urls
# Processed 3360 songs
# Processed 3365 songs
# Processed 3370 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/23 urls
# Processed 3375 songs
# Processed 3380 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/22 urls
# Processed 3385 songs
# Processed 3390 songs
# Processed 3395 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/21 urls
# Processed 3400 songs
# Processed 3405 songs
# Processed 3410 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/20 urls
# Processed 3415 songs
# Processed 3420 songs
# Processed 3425 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/19 urls
# Processed 3430 songs
# Processed 3435 songs
# Processed 3440 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/18 urls
# Processed 3445 songs
# Processed 3450 songs
# Processed 3455 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/17 urls
# Processed 3460 songs
# Processed 3465 songs
# Processed 3470 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/16 urls
# Processed 3475 songs
# Processed 3480 songs
# Processed 3485 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/15 urls
# Processed 3490 songs
# Processed 3495 songs
# Processed 3500 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/14 urls
# Processed 3505 songs
# Processed 3510 songs
# Processed 3515 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/13 urls
# Processed 3520 songs
# Processed 3525 songs
# Processed 3530 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/12 urls
# Processed 3535 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/11 urls
# Processed 3540 songs
# Processed 3545 songs
# Processed 3550 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/10 urls
# Processed 3555 songs
# Processed 3560 songs
# Processed 3565 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/09 urls
# Processed 3570 songs
# Processed 3575 songs
# Processed 3580 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/08 urls
# Processed 3585 songs
# Processed 3590 songs
# Processed 3595 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/07 urls
# Processed 3600 songs
# Processed 3605 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/06 urls
# Processed 3610 songs
# Processed 3615 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/05 urls
# Processed 3620 songs
# Processed 3625 songs
# Processed 3630 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/04 urls
# Processed 3635 songs
# Processed 3640 songs
# Processed 3645 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/03 urls
# Processed 3650 songs
# Processed 3655 songs
# Processed 3660 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/02 urls
# Processed 3665 songs
# Processed 3670 songs
# Processed 3675 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/01 urls
# Processed 3680 songs
# Processed 3685 songs
# Processed 3690 songs
# Starting http://www.thecurrent.org/playlist/2017-05-01/00 urls
# Processed 3695 songs
# Processed 3700 songs
# Processed 3705 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/23 urls
# Processed 3710 songs
# Processed 3715 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/22 urls
# Processed 3720 songs
# Processed 3725 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/21 urls
# Processed 3730 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/20 urls
# Starting http://www.thecurrent.org/playlist/2017-04-30/19 urls
# Processed 3735 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/18 urls
# Processed 3740 songs
# Processed 3745 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/17 urls
# Processed 3750 songs
# Processed 3755 songs
# Processed 3760 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/16 urls
# Processed 3765 songs
# Processed 3770 songs
# Processed 3775 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/15 urls
# Processed 3780 songs
# Processed 3785 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/14 urls
# Processed 3790 songs
# Processed 3795 songs
# Processed 3800 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/13 urls
# Processed 3805 songs
# Processed 3810 songs
# Processed 3815 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/12 urls
# Processed 3820 songs
# Processed 3825 songs
# Processed 3830 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/11 urls
# Processed 3835 songs
# Processed 3840 songs
# Processed 3845 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/10 urls
# Processed 3850 songs
# Processed 3855 songs
# Processed 3860 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/09 urls
# Processed 3865 songs
# Processed 3870 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/08 urls
# Processed 3875 songs
# Processed 3880 songs
# Processed 3885 songs
# Processed 3890 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/07 urls
# Starting http://www.thecurrent.org/playlist/2017-04-30/06 urls
# Starting http://www.thecurrent.org/playlist/2017-04-30/05 urls
# Processed 3895 songs
# Processed 3900 songs
# Processed 3905 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/04 urls
# Processed 3910 songs
# Processed 3915 songs
# Processed 3920 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/03 urls
# Processed 3925 songs
# Processed 3930 songs
# Processed 3935 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/02 urls
# Processed 3940 songs
# Processed 3945 songs
# Processed 3950 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/01 urls
# Processed 3955 songs
# Processed 3960 songs
# Processed 3965 songs
# Starting http://www.thecurrent.org/playlist/2017-04-30/00 urls
# Starting http://www.thecurrent.org/playlist/2017-04-29/23 urls
# Processed 3970 songs
# Processed 3975 songs
# Processed 3980 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/22 urls
# Processed 3985 songs
# Processed 3990 songs
# Processed 3995 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/21 urls
# Processed 4000 songs
# Processed 4005 songs
# Processed 4010 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/20 urls
# Processed 4015 songs
# Processed 4020 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/19 urls
# Processed 4025 songs
# Processed 4030 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/18 urls
# Processed 4035 songs
# Processed 4040 songs
# Processed 4045 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/17 urls
# Processed 4050 songs
# Processed 4055 songs
# Processed 4060 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/16 urls
# Processed 4065 songs
# Processed 4070 songs
# Processed 4075 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/15 urls
# Processed 4080 songs
# Processed 4085 songs
# Processed 4090 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/14 urls
# Processed 4095 songs
# Processed 4100 songs
# Processed 4105 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/13 urls
# Processed 4110 songs
# Processed 4115 songs
# Processed 4120 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/12 urls
# Processed 4125 songs
# Processed 4130 songs
# Processed 4135 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/11 urls
# Processed 4140 songs
# Processed 4145 songs
# Processed 4150 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/10 urls
# Processed 4155 songs
# Processed 4160 songs
# Processed 4165 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/09 urls
# Processed 4170 songs
# Processed 4175 songs
# Processed 4180 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/08 urls
# Processed 4185 songs
# Processed 4190 songs
# Processed 4195 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/07 urls
# Processed 4200 songs
# Processed 4205 songs
# Processed 4210 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/06 urls
# Processed 4215 songs
# Processed 4220 songs
# Processed 4225 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/05 urls
# Processed 4230 songs
# Processed 4235 songs
# Processed 4240 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/04 urls
# Processed 4245 songs
# Processed 4250 songs
# Processed 4255 songs
# Processed 4260 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/03 urls
# Processed 4265 songs
# Processed 4270 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/02 urls
# Processed 4275 songs
# Processed 4280 songs
# Processed 4285 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/01 urls
# Processed 4290 songs
# Processed 4295 songs
# Processed 4300 songs
# Starting http://www.thecurrent.org/playlist/2017-04-29/00 urls
# Processed 4305 songs
# Processed 4310 songs
# Processed 4315 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/23 urls
# Processed 4320 songs
# Processed 4325 songs
# Processed 4330 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/22 urls
# Processed 4335 songs
# Processed 4340 songs
# Processed 4345 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/21 urls
# Processed 4350 songs
# Processed 4355 songs
# Processed 4360 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/20 urls
# Processed 4365 songs
# Processed 4370 songs
# Processed 4375 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/19 urls
# Processed 4380 songs
# Processed 4385 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/18 urls
# Processed 4390 songs
# Processed 4395 songs
# Processed 4400 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/17 urls
# Processed 4405 songs
# Processed 4410 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/16 urls
# Processed 4415 songs
# Processed 4420 songs
# Processed 4425 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/15 urls
# Processed 4430 songs
# Processed 4435 songs
# Processed 4440 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/14 urls
# Processed 4445 songs
# Processed 4450 songs
# Processed 4455 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/13 urls
# Processed 4460 songs
# Processed 4465 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/12 urls
# Processed 4470 songs
# Processed 4475 songs
# Processed 4480 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/11 urls
# Processed 4485 songs
# Processed 4490 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/10 urls
# Processed 4495 songs
# Processed 4500 songs
# Processed 4505 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/09 urls
# Processed 4510 songs
# Processed 4515 songs
# Processed 4520 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/08 urls
# Processed 4525 songs
# Processed 4530 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/07 urls
# Processed 4535 songs
# Processed 4540 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/06 urls
# Processed 4545 songs
# Processed 4550 songs
# Processed 4555 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/05 urls
# Processed 4560 songs
# Processed 4565 songs
# Processed 4570 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/04 urls
# Processed 4575 songs
# Processed 4580 songs
# Processed 4585 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/03 urls
# Processed 4590 songs
# Processed 4595 songs
# Processed 4600 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/02 urls
# Processed 4605 songs
# Processed 4610 songs
# Processed 4615 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/01 urls
# Processed 4620 songs
# Processed 4625 songs
# Processed 4630 songs
# Processed 4635 songs
# Starting http://www.thecurrent.org/playlist/2017-04-28/00 urls
# Processed 4640 songs
# Processed 4645 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/23 urls
# Processed 4650 songs
# Processed 4655 songs
# Processed 4660 songs
# Processed 4665 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/22 urls
# Processed 4670 songs
# Processed 4675 songs
# Processed 4680 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/21 urls
# Processed 4685 songs
# Processed 4690 songs
# Processed 4695 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/20 urls
# Processed 4700 songs
# Processed 4705 songs
# Processed 4710 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/19 urls
# Processed 4715 songs
# Processed 4720 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/18 urls
# Processed 4725 songs
# Processed 4730 songs
# Processed 4735 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/17 urls
# Processed 4740 songs
# Processed 4745 songs
# Processed 4750 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/16 urls
# Processed 4755 songs
# Processed 4760 songs
# Processed 4765 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/15 urls
# Processed 4770 songs
# Processed 4775 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/14 urls
# Processed 4780 songs
# Processed 4785 songs
# Processed 4790 songs
# Processed 4795 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/13 urls
# Processed 4800 songs
# Processed 4805 songs
# Processed 4810 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/12 urls
# Processed 4815 songs
# Processed 4820 songs
# Processed 4825 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/11 urls
# Processed 4830 songs
# Processed 4835 songs
# Processed 4840 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/10 urls
# Processed 4845 songs
# Processed 4850 songs
# Processed 4855 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/09 urls
# Processed 4860 songs
# Processed 4865 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/08 urls
# Processed 4870 songs
# Processed 4875 songs
# Processed 4880 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/07 urls
# Processed 4885 songs
# Processed 4890 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/06 urls
# Processed 4895 songs
# Processed 4900 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/05 urls
# Processed 4905 songs
# Processed 4910 songs
# Processed 4915 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/04 urls
# Processed 4920 songs
# Processed 4925 songs
# Processed 4930 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/03 urls
# Processed 4935 songs
# Processed 4940 songs
# Processed 4945 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/02 urls
# Processed 4950 songs
# Processed 4955 songs
# Processed 4960 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/01 urls
# Processed 4965 songs
# Processed 4970 songs
# Processed 4975 songs
# Starting http://www.thecurrent.org/playlist/2017-04-27/00 urls
# Processed 4980 songs
# Processed 4985 songs
# Processed 4990 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/23 urls
# Processed 4995 songs
# Processed 5000 songs
# Processed 5005 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/22 urls
# Starting http://www.thecurrent.org/playlist/2017-04-26/21 urls
# Processed 5010 songs
# Processed 5015 songs
# Processed 5020 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/20 urls
# Processed 5025 songs
# Processed 5030 songs
# Processed 5035 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/19 urls
# Processed 5040 songs
# Processed 5045 songs
# Processed 5050 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/18 urls
# Processed 5055 songs
# Processed 5060 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/17 urls
# Processed 5065 songs
# Processed 5070 songs
# Processed 5075 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/16 urls
# Processed 5080 songs
# Processed 5085 songs
# Processed 5090 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/15 urls
# Processed 5095 songs
# Processed 5100 songs
# Processed 5105 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/14 urls
# Processed 5110 songs
# Processed 5115 songs
# Processed 5120 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/13 urls
# Processed 5125 songs
# Processed 5130 songs
# Processed 5135 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/12 urls
# Processed 5140 songs
# Processed 5145 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/11 urls
# Processed 5150 songs
# Processed 5155 songs
# Processed 5160 songs
# Processed 5165 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/10 urls
# Processed 5170 songs
# Processed 5175 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/09 urls
# Processed 5180 songs
# Processed 5185 songs
# Processed 5190 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/08 urls
# Processed 5195 songs
# Processed 5200 songs
# Processed 5205 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/07 urls
# Processed 5210 songs
# Processed 5215 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/06 urls
# Processed 5220 songs
# Processed 5225 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/05 urls
# Processed 5230 songs
# Processed 5235 songs
# Processed 5240 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/04 urls
# Processed 5245 songs
# Processed 5250 songs
# Processed 5255 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/03 urls
# Processed 5260 songs
# Processed 5265 songs
# Processed 5270 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/02 urls
# Processed 5275 songs
# Processed 5280 songs
# Processed 5285 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/01 urls
# Processed 5290 songs
# Processed 5295 songs
# Processed 5300 songs
# Starting http://www.thecurrent.org/playlist/2017-04-26/00 urls
# Processed 5305 songs
# Processed 5310 songs
# Processed 5315 songs
# Starting http://www.thecurrent.org/playlist/2017-04-25/23 urls
# Processed 5320 songs
# Processed 5325 songs
# Processed 5330 songs
# Starting http://www.thecurrent.org/playlist/2017-04-25/22 urls
# Processed 5335 songs
# Processed 5340 songs
# Processed 5345 songs
# Starting http://www.thecurrent.org/playlist/2017-04-25/21 urls
# Processed 5350 songs
# Processed 5355 songs
# ...
# Processed 16645 songs
# Processed 16650 songs
# Starting http://www.thecurrent.org/playlist/2017-03-21/17 urls
# Processed 16655 songs
# Processed 16660 songs
# Starting http://www.thecurrent.org/playlist/2017-03-21/16 urls
# Processed 16665 songs
# Processed 16670 songs
# Processed 16675 songs
# Starting http://www.thecurrent.org/playlist/2017-03-21/15 urls
# Processed 16680 songs
# Processed 16685 songs
# Processed 16690 songs
# Starting http://www.thecurrent.org/playlist/2017-03-21/14 urls
# Processed 16695 songs
# Processed 16700 songs
# Starting http://www.thecurrent.org/playlist/2017-03-21/13 urls
# Processed 16705 songs
# Processed 16710 songs
# Processed 16715 songs
# Starting http://www.thecurrent.org/playlist/2017-03-21/12 urls
# Processed 16720 songs
# Processed 16725 songs
# Processed 16730 songs
# Starting http://www.thecurrent.org/playlist/2017-03-21/11 urls
# Processed 16735 songs
# Processed 16740 songs
# Starting http://www.thecurrent.org/playlist/2017-03-21/10 urls
# Processed 16745 songs
# Processed 16750 songs
# Processed 16755 songs
# Starting http://www.thecurrent.org/playlist/2017-03-21/09 urls
# Processed 16760 songs
# Processed 16765 songs
# Starting http://www.thecurrent.org/playlist/2017-03-21/08 urls
# Processed 16770 songs
# Processed 16775 songs
# Processed 16780 songs
# Starting http://www.thecurrent.org/playlist/2017-03-21/07 urls
# Processed 16785 songs
# Processed 16790 songs
# Starting http://www.thecurrent.org/playlist/2017-03-21/06 urls
# Processed 16795 songs
# Processed 16800 songs
# Starting http://www.thecurrent.org/playlist/2017-03-21/05 urls
# Processed 16805 songs
# Processed 16810 songs
# Processed 16815 songs
# Starting http://www.thecurrent.org/playlist/2017-03-21/04 urls
# Processed 16820 songs
# Processed 16825 songs
# Processed 16830 songs
# Starting http://www.thecurrent.org/playlist/2017-03-21/03 urls
# Processed 16835 songs
# Processed 16840 songs
# Processed 16845 songs
# Processed 16850 songs
# Starting http://www.thecurrent.org/playlist/2017-03-21/02 urls
# Processed 16855 songs
# Processed 16860 songs
# Processed 16865 songs
# Starting http://www.thecurrent.org/playlist/2017-03-21/01 urls
# Processed 16870 songs
# Processed 16875 songs
# Processed 16880 songs
# Starting http://www.thecurrent.org/playlist/2017-03-21/00 urls
# Processed 16885 songs
# Processed 16890 songs
# Processed 16895 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/23 urls
# Processed 16900 songs
# Processed 16905 songs
# Processed 16910 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/22 urls
# Processed 16915 songs
# Processed 16920 songs
# Processed 16925 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/21 urls
# Processed 16930 songs
# Processed 16935 songs
# Processed 16940 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/20 urls
# Processed 16945 songs
# Processed 16950 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/19 urls
# Processed 16955 songs
# Processed 16960 songs
# Processed 16965 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/18 urls
# Processed 16970 songs
# Processed 16975 songs
# Processed 16980 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/17 urls
# Processed 16985 songs
# Processed 16990 songs
# Processed 16995 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/16 urls
# Processed 17000 songs
# Processed 17005 songs
# Processed 17010 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/15 urls
# Processed 17015 songs
# Processed 17020 songs
# Processed 17025 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/14 urls
# Processed 17030 songs
# Processed 17035 songs
# Processed 17040 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/13 urls
# Processed 17045 songs
# Processed 17050 songs
# Processed 17055 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/12 urls
# Processed 17060 songs
# Processed 17065 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/11 urls
# Processed 17070 songs
# Processed 17075 songs
# Processed 17080 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/10 urls
# Processed 17085 songs
# Processed 17090 songs
# Processed 17095 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/09 urls
# Processed 17100 songs
# Processed 17105 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/08 urls
# Processed 17110 songs
# Processed 17115 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/07 urls
# Processed 17120 songs
# Processed 17125 songs
# Processed 17130 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/06 urls
# Processed 17135 songs
# Processed 17140 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/05 urls
# Processed 17145 songs
# Processed 17150 songs
# Processed 17155 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/04 urls
# Processed 17160 songs
# Processed 17165 songs
# Processed 17170 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/03 urls
# Processed 17175 songs
# Processed 17180 songs
# Processed 17185 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/02 urls
# Processed 17190 songs
# Processed 17195 songs
# Processed 17200 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/01 urls
# Processed 17205 songs
# Processed 17210 songs
# Processed 17215 songs
# Starting http://www.thecurrent.org/playlist/2017-03-20/00 urls
# Processed 17220 songs
# Processed 17225 songs
# Processed 17230 songs
# Starting http://www.thecurrent.org/playlist/2017-03-19/23 urls
# Processed 17235 songs
# Processed 17240 songs
# Starting http://www.thecurrent.org/playlist/2017-03-19/22 urls
# Processed 17245 songs
# Processed 17250 songs
# Starting http://www.thecurrent.org/playlist/2017-03-19/21 urls
# Processed 17255 songs
# Starting http://www.thecurrent.org/playlist/2017-03-19/20 urls
# Starting http://www.thecurrent.org/playlist/2017-03-19/19 urls
# Processed 17260 songs
# Processed 17265 songs
# Processed 17270 songs
# Starting http://www.thecurrent.org/playlist/2017-03-19/18 urls
# Processed 17275 songs
# Processed 17280 songs
# Starting http://www.thecurrent.org/playlist/2017-03-19/17 urls
# Processed 17285 songs
# Processed 17290 songs
# Processed 17295 songs
# Processed 17300 songs
# Starting http://www.thecurrent.org/playlist/2017-03-19/16 urls
# Processed 17305 songs
# Processed 17310 songs
# Starting http://www.thecurrent.org/playlist/2017-03-19/15 urls
# Processed 17315 songs
# Processed 17320 songs
# Processed 17325 songs
# Starting http://www.thecurrent.org/playlist/2017-03-19/14 urls
# Processed 17330 songs
# Processed 17335 songs
# Processed 17340 songs
# Starting http://www.thecurrent.org/playlist/2017-03-19/13 urls
# Processed 17345 songs
# Processed 17350 songs
# Processed 17355 songs
# Starting http://www.thecurrent.org/playlist/2017-03-19/12 urls
# Processed 17360 songs
# Processed 17365 songs
# Processed 17370 songs
# Starting http://www.thecurrent.org/playlist/2017-03-19/11 urls
# Processed 17375 songs
# Processed 17380 songs
# Processed 17385 songs
# Starting http://www.thecurrent.org/playlist/2017-03-19/10 urls
# Processed 17390 songs
# Processed 17395 songs
# Processed 17400 songs
# Starting http://www.thecurrent.org/playlist/2017-03-19/09 urls
# Processed 17405 songs
# Processed 17410 songs
# Starting http://www.thecurrent.org/playlist/2017-03-19/08 urls
# Processed 17415 songs
# Processed 17420 songs
# Processed 17425 songs
# Starting http://www.thecurrent.org/playlist/2017-03-19/07 urls
# Starting http://www.thecurrent.org/playlist/2017-03-19/06 urls
# Starting http://www.thecurrent.org/playlist/2017-03-19/05 urls
# Starting http://www.thecurrent.org/playlist/2017-03-19/04 urls
# Starting http://www.thecurrent.org/playlist/2017-03-19/03 urls
# Starting http://www.thecurrent.org/playlist/2017-03-19/02 urls
# Starting http://www.thecurrent.org/playlist/2017-03-19/01 urls
# Processed 17430 songs
# Processed 17435 songs
# Starting http://www.thecurrent.org/playlist/2017-03-19/00 urls
# Starting http://www.thecurrent.org/playlist/2017-03-18/23 urls
# Processed 17440 songs
# Processed 17445 songs
# Processed 17450 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/22 urls
# Processed 17455 songs
# Processed 17460 songs
# Processed 17465 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/21 urls
# Processed 17470 songs
# Processed 17475 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/20 urls
# Processed 17480 songs
# Processed 17485 songs
# Processed 17490 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/19 urls
# Processed 17495 songs
# Processed 17500 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/18 urls
# Processed 17505 songs
# Processed 17510 songs
# Processed 17515 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/17 urls
# Processed 17520 songs
# Processed 17525 songs
# Processed 17530 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/16 urls
# Processed 17535 songs
# Processed 17540 songs
# Processed 17545 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/15 urls
# Processed 17550 songs
# Processed 17555 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/14 urls
# Processed 17560 songs
# Processed 17565 songs
# Processed 17570 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/13 urls
# Processed 17575 songs
# Processed 17580 songs
# Processed 17585 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/12 urls
# Processed 17590 songs
# Processed 17595 songs
# Processed 17600 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/11 urls
# Processed 17605 songs
# Processed 17610 songs
# Processed 17615 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/10 urls
# Processed 17620 songs
# Processed 17625 songs
# Processed 17630 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/09 urls
# Processed 17635 songs
# Processed 17640 songs
# Processed 17645 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/08 urls
# Processed 17650 songs
# Processed 17655 songs
# Processed 17660 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/07 urls
# Processed 17665 songs
# Processed 17670 songs
# Processed 17675 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/06 urls
# Processed 17680 songs
# Processed 17685 songs
# Processed 17690 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/05 urls
# Processed 17695 songs
# Processed 17700 songs
# Processed 17705 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/04 urls
# Processed 17710 songs
# Processed 17715 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/03 urls
# Processed 17720 songs
# Processed 17725 songs
# Processed 17730 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/02 urls
# Processed 17735 songs
# Processed 17740 songs
# Processed 17745 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/01 urls
# Processed 17750 songs
# Processed 17755 songs
# Processed 17760 songs
# Starting http://www.thecurrent.org/playlist/2017-03-18/00 urls
# Processed 17765 songs
# Processed 17770 songs
# Processed 17775 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/23 urls
# Processed 17780 songs
# Processed 17785 songs
# Processed 17790 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/22 urls
# Processed 17795 songs
# Processed 17800 songs
# Processed 17805 songs
# Processed 17810 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/21 urls
# Processed 17815 songs
# Processed 17820 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/20 urls
# Processed 17825 songs
# Processed 17830 songs
# Processed 17835 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/19 urls
# Processed 17840 songs
# Processed 17845 songs
# Processed 17850 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/18 urls
# Processed 17855 songs
# Processed 17860 songs
# Processed 17865 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/17 urls
# Processed 17870 songs
# Processed 17875 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/16 urls
# Processed 17880 songs
# Processed 17885 songs
# Processed 17890 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/15 urls
# Processed 17895 songs
# Processed 17900 songs
# Processed 17905 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/14 urls
# Processed 17910 songs
# Processed 17915 songs
# Processed 17920 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/13 urls
# Processed 17925 songs
# Processed 17930 songs
# Processed 17935 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/12 urls
# Processed 17940 songs
# Processed 17945 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/11 urls
# Processed 17950 songs
# Processed 17955 songs
# Processed 17960 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/10 urls
# Processed 17965 songs
# Processed 17970 songs
# Processed 17975 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/09 urls
# Processed 17980 songs
# Processed 17985 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/08 urls
# Processed 17990 songs
# Processed 17995 songs
# Processed 18000 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/07 urls
# Processed 18005 songs
# Processed 18010 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/06 urls
# Processed 18015 songs
# Processed 18020 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/05 urls
# Processed 18025 songs
# Processed 18030 songs
# Processed 18035 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/04 urls
# Processed 18040 songs
# Processed 18045 songs
# Processed 18050 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/03 urls
# Processed 18055 songs
# Processed 18060 songs
# Processed 18065 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/02 urls
# Processed 18070 songs
# Processed 18075 songs
# Processed 18080 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/01 urls
# Processed 18085 songs
# Processed 18090 songs
# Processed 18095 songs
# Starting http://www.thecurrent.org/playlist/2017-03-17/00 urls
# Processed 18100 songs
# Processed 18105 songs
# Processed 18110 songs
# Starting http://www.thecurrent.org/playlist/2017-03-16/23 urls
# Processed 18115 songs
# Processed 18120 songs
# Processed 18125 songs
# Starting http://www.thecurrent.org/playlist/2017-03-16/22 urls
# Processed 18130 songs
# Processed 18135 songs
# Processed 18140 songs
# Starting http://www.thecurrent.org/playlist/2017-03-16/21 urls
# Processed 18145 songs
# Processed 18150 songs
# Processed 18155 songs
# Starting http://www.thecurrent.org/playlist/2017-03-16/20 urls
# Processed 18160 songs
# Processed 18165 songs
# Processed 18170 songs
# Starting http://www.thecurrent.org/playlist/2017-03-16/19 urls
# Processed 18175 songs
# Processed 18180 songs
# Processed 18185 songs
# Starting http://www.thecurrent.org/playlist/2017-03-16/18 urls
# Processed 18190 songs
# Processed 18195 songs
# Starting http://www.thecurrent.org/playlist/2017-03-16/17 urls
# Processed 18200 songs
# Processed 18205 songs
# Processed 18210 songs
# Starting http://www.thecurrent.org/playlist/2017-03-16/16 urls
# Processed 18215 songs
# Processed 18220 songs
# Processed 18225 songs
# Starting http://www.thecurrent.org/playlist/2017-03-16/15 urls
# Processed 18230 songs
# Processed 18235 songs
# Processed 18240 songs
# Starting http://www.thecurrent.org/playlist/2017-03-16/14 urls
# Processed 18245 songs
# Processed 18250 songs
# Processed 18255 songs
# Starting http://www.thecurrent.org/playlist/2017-03-16/13 urls
# Processed 18260 songs
# Processed 18265 songs
# Processed 18270 songs
# Starting http://www.thecurrent.org/playlist/2017-03-16/12 urls
# Processed 18275 songs
# Processed 18280 songs
# Processed 18285 songs
# Starting http://www.thecurrent.org/playlist/2017-03-16/11 urls
# Processed 18290 songs
# Processed 18295 songs
# Processed 18300 songs
# Starting http://www.thecurrent.org/playlist/2017-03-16/10 urls
# Processed 18305 songs
# Processed 18310 songs
# Processed 18315 songs
# Starting http://www.thecurrent.org/playlist/2017-03-16/09 urls
# Processed 18320 songs
# Processed 18325 songs
# Starting http://www.thecurrent.org/playlist/2017-03-16/08 urls
# Processed 18330 songs
# Processed 18335 songs
# Processed 18340 songs
# Starting http://www.thecurrent.org/playlist/2017-03-16/07 urls
# Processed 18345 songs
# Processed 18350 songs
# Starting http://www.thecurrent.org/playlist/2017-03-16/06 urls
# Processed 18355 songs
# Processed 18360 songs
# Processed 18365 songs
# Starting http://www.thecurrent.org/playlist/2017-03-16/05 urls
